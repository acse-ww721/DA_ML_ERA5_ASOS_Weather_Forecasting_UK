# %%
# Basic setting for Jupyter_notebook to import utils
import os
import sys

notebook_path = os.path.abspath("")
project_root = os.path.abspath(os.path.join(notebook_path, "../../"))

sys.path.append(project_root)

# %% [markdown]
# # 2 ERA5_DATA_PROCESSING

# %% [markdown]
# ## Data EDA

# %%
import os
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from utils import folder_utils
from tqdm import tqdm

# %%
# Example usage

country = "GB"
data_folder = "data"
data_test_category = "test_data"
data_read_category = "raw_data"
data_save_category = "processed_data"
# output_folder = "ASOS_DATA"
output_folder2 ="ERA5_DATA"

# %%
folder_utils.create_folder( country, data_folder, data_test_category, output_folder2)
# Out:
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/test_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
# '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/test_data/ERA5_DATA/GB_ERA5_DATA'

# %%
def extract_data_nc_to_xr(country, data_folder, data_category, output_folder):
    # Specify the folder path
    input_folder_path = folder_utils.find_folder(
        country, data_folder, data_category, output_folder
    )
    raw_ds = None  # Initialize raw_ds outside the loop
    nc_files = [
        f
        for f in os.listdir(input_folder_path)
        if f.endswith('.nc') and "era5_station_network" not in f
    ]
    # Read and merge the csv files in queue
    for nc_file in tqdm(nc_files):
        nc_file_path = os.path.join(input_folder_path, nc_file)
        raw_ds = xr.open_dataset(nc_file_path)
        # raw_df = pd.concat([raw_df, df], ignore_index=True)

    return raw_ds

# %%
ds = extract_data_nc_to_xr(country, data_folder, data_test_category, output_folder2)
# Out:
# 100%|███████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.38it/s]

# %%
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 41, latitude: 45, time: 744)
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Data variables:
#     u10        (time, latitude, longitude) float32 ...
#     v10        (time, latitude, longitude) float32 ...
#     d2m        (time, latitude, longitude) float32 ...
#     t2m        (time, latitude, longitude) float32 ...
#     i10fg      (time, latitude, longitude) float32 ...
#     msl        (time, latitude, longitude) float32 ...
#     skt        (time, latitude, longitude) float32 ...
#     sp         (time, latitude, longitude) float32 ...
#     tp         (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-14 13:08:35 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
ds.dims
# Out:
# Frozen({'longitude': 41, 'latitude': 45, 'time': 744})

# %%
ds.data_vars
# Out:
# Data variables:
#     u10      (time, latitude, longitude) float32 ...
#     v10      (time, latitude, longitude) float32 ...
#     d2m      (time, latitude, longitude) float32 ...
#     t2m      (time, latitude, longitude) float32 ...
#     i10fg    (time, latitude, longitude) float32 ...
#     msl      (time, latitude, longitude) float32 ...
#     skt      (time, latitude, longitude) float32 ...
#     sp       (time, latitude, longitude) float32 ...
#     tp       (time, latitude, longitude) float32 ...

# %%
ds.coords
# Out:
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00

# %%
ds.attrs
# Out:
# {'Conventions': 'CF-1.6',
#  'history': '2023-08-14 13:08:35 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data9/adaptor.mars.internal-1692018500.2390654-25204-1-38ad28e7-7189-4dcf-abc4-d4ef8d4cf8e3.nc /cache/tmp/38ad28e7-7189-4dcf-abc4-d4ef8d4cf8e3-adaptor.mars.internal-1692018168.885484-25204-1-tmp.grib'}

# %%
ds.longitude
# Out:
# <xarray.DataArray 'longitude' (longitude: 41)>
# array([-8.  , -7.75, -7.5 , -7.25, -7.  , -6.75, -6.5 , -6.25, -6.  , -5.75,
#        -5.5 , -5.25, -5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25,
#        -3.  , -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,  1.75,
#         2.  ], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
# Attributes:
#     units:      degrees_east
#     long_name:  longitude

# %%
ds.latitude
# Out:
# <xarray.DataArray 'latitude' (latitude: 45)>
# array([61.  , 60.75, 60.5 , 60.25, 60.  , 59.75, 59.5 , 59.25, 59.  , 58.75,
#        58.5 , 58.25, 58.  , 57.75, 57.5 , 57.25, 57.  , 56.75, 56.5 , 56.25,
#        56.  , 55.75, 55.5 , 55.25, 55.  , 54.75, 54.5 , 54.25, 54.  , 53.75,
#        53.5 , 53.25, 53.  , 52.75, 52.5 , 52.25, 52.  , 51.75, 51.5 , 51.25,
#        51.  , 50.75, 50.5 , 50.25, 50.  ], dtype=float32)
# Coordinates:
#   * latitude  (latitude) float32 61.0 60.75 60.5 60.25 ... 50.75 50.5 50.25 50.0
# Attributes:
#     units:      degrees_north
#     long_name:  latitude

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 744)>
# array(['2023-01-01T00:00:00.000000000', '2023-01-01T01:00:00.000000000',
#        '2023-01-01T02:00:00.000000000', ..., '2023-01-31T21:00:00.000000000',
#        '2023-01-31T22:00:00.000000000', '2023-01-31T23:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     long_name:  time

# %%
ds.d2m.attrs
# Out:
# {'units': 'K', 'long_name': '2 metre dewpoint temperature'}

# %%
ds.d2m.long_name
# Out:
# '2 metre dewpoint temperature'

# %%
ds.longitude.shape
# Out:
# (41,)

# %%
ds.latitude.shape[0]
# Out:
# 45

# %%
ds.latitude.shape
# Out:
# (45,)

# %%
ds.latitude.values[0]
# Out:
# 61.0

# %%
ds.d2m.shape
# Out:
# (744, 45, 41)

# %%
print('Latitudes and longitudes of domain corners:')
pt1 = 0
pt2 = 0
print('  0, 0:        ', ds.latitude.values[pt1], ds.longitude.values[pt2])
pt1 = ds.latitude.shape[0] - 1
print('  0, x-max:    ', ds.latitude.values[pt1], ds.longitude.values[pt2])
pt = ds.latitude.shape[0] - 1
print('  y-max, 0:    ', ds.latitude.values[pt], ds.longitude.values[pt])
pt = ds.latitude.shape[0] - 1
pt2 = ds.longitude.shape[0] - 1
print('  y-max, x-max:', ds.latitude.values[pt], ds.longitude.values[pt2])
# Out:
# Latitudes and longitudes of domain corners:
#   0, 0:         61.0 -8.0
#   0, x-max:     50.0 -8.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 8
#       6 print('  0, x-max:    ', ds.latitude.values[pt1], ds.longitude.values[pt2])
#       7 pt = ds.latitude.shape[0] - 1
# ----> 8 print('  y-max, 0:    ', ds.latitude.values[pt], ds.longitude.values[pt])
#       9 pt = ds.latitude.shape[0] - 1
#      10 pt2 = ds.longitude.shape[0] - 1
#
# IndexError: index 44 is out of bounds for axis 0 with size 41

# %%
ds.latitude.values # 提取数值
# Out:
# array([61.  , 60.75, 60.5 , 60.25, 60.  , 59.75, 59.5 , 59.25, 59.  ,
#        58.75, 58.5 , 58.25, 58.  , 57.75, 57.5 , 57.25, 57.  , 56.75,
#        56.5 , 56.25, 56.  , 55.75, 55.5 , 55.25, 55.  , 54.75, 54.5 ,
#        54.25, 54.  , 53.75, 53.5 , 53.25, 53.  , 52.75, 52.5 , 52.25,
#        52.  , 51.75, 51.5 , 51.25, 51.  , 50.75, 50.5 , 50.25, 50.  ],
#       dtype=float32)

# %%
ds.latitude.values[3:5]   # like numpy
# Out:
# array([60.25, 60.  ], dtype=float32)

# %%
# Data Description
for i in ds.data_vars:
    print("--------------------------------------------------------------------")
    print(i)
    print("--------------------------------------------------------------------")
    var_data = ds[i]
    print(var_data)
# Out:
# --------------------------------------------------------------------
# u10
# --------------------------------------------------------------------
# <xarray.DataArray 'u10' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:      m s**-1
#     long_name:  10 metre U wind component
# --------------------------------------------------------------------
# v10
# --------------------------------------------------------------------
# <xarray.DataArray 'v10' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:      m s**-1
#     long_name:  10 metre V wind component
# --------------------------------------------------------------------
# d2m
# --------------------------------------------------------------------
# <xarray.DataArray 'd2m' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:      K
#     long_name:  2 metre dewpoint temperature
# --------------------------------------------------------------------
# t2m
# --------------------------------------------------------------------
# <xarray.DataArray 't2m' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:      K
#     long_name:  2 metre temperature
# --------------------------------------------------------------------
# i10fg
# --------------------------------------------------------------------
# <xarray.DataArray 'i10fg' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:      m s**-1
#     long_name:  Instantaneous 10 metre wind gust
# --------------------------------------------------------------------
# msl
# --------------------------------------------------------------------
# <xarray.DataArray 'msl' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:          Pa
#     long_name:      Mean sea level pressure
#     standard_name:  air_pressure_at_mean_sea_level
# --------------------------------------------------------------------
# skt
# --------------------------------------------------------------------
# <xarray.DataArray 'skt' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:      K
#     long_name:  Skin temperature
# --------------------------------------------------------------------
# sp
# --------------------------------------------------------------------
# <xarray.DataArray 'sp' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-31T23:00:00
# Attributes:
#     units:          Pa
#     long_name:      Surface pressure
#     standard_name:  surface_air_pressure
# --------------------------------------------------------------------
# tp
# --------------------------------------------------------------------
# <xarray.DataArray 'tp' (time: 744, latitude: 45, longitude: 41)>
# [1372680 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 

#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    4.75673005e-07 1.42678618e-06]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 4.75673005e-07
#    4.75673005e-07 4.75673005e-07]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 4.75673005e-07
#    2.85357237e-06 7.13369809e-06]]
#
#  [[6.81884354e-04 8.54994869e-04 9.58480639e-04 ... 1.19655626e-04
#    9.15965065e-05 7.77095556e-05]
#   [5.55951148e-04 6.59912592e-04 7.91077036e-04 ... 2.08874000e-04
#    9.58766323e-05 7.77095556e-05]
#   [2.64611794e-04 2.77547631e-04 3.70475464e-04 ... 1.47809740e-04
#    1.79293100e-04 2.19812384e-04]
#   ...
#   [1.42678618e-06 9.51113179e-07 9.51113179e-07 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [4.75673005e-07 9.51113179e-07 1.42678618e-06 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 4.75673005e-07 9.51113179e-07 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[4.76814806e-04 3.69048910e-04 3.69048910e-04 ... 1.15850940e-04
#    6.77222852e-05 8.72211531e-05]
#   [4.40575881e-04 5.85532049e-04 6.88066706e-04 ... 6.91490714e-05
#    7.58070964e-05 9.11208335e-05]
#   [5.44061651e-04 6.74750656e-04 8.25889409e-04 ... 1.22033525e-04
#    1.68354716e-04 2.40357360e-04]
#   ...
#   [3.32901254e-06 6.65802509e-06 9.51159745e-06 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [9.51113179e-07 1.90222636e-06 4.75579873e-06 ... 4.75673005e-07
#    4.75673005e-07 0.00000000e+00]
#   [0.00000000e+00 1.42678618e-06 2.37789936e-06 ... 4.75673005e-07
#    0.00000000e+00 0.00000000e+00]]]

# %%
def extract_data_nc_to_xr(country, data_folder, data_category, output_folder):
    # Specify the folder path
    input_folder_path = folder_utils.find_folder(
        country, data_folder, data_category, output_folder
    )
    raw_ds = None  # Initialize raw_ds outside the loop
    nc_files = [
        f
        for f in os.listdir(input_folder_path)
        if f.endswith('.nc') and "era5_station_network" not in f
    ]
    # Read and merge the csv files in queue
    nc_files_path =[]
    for nc_file in tqdm(nc_files):
        nc_file_path = os.path.join(input_folder_path, nc_file)
        nc_files_path.append(nc_file_path)
        # raw_ds = xr.open_dataset(nc_file_path)
        # raw_df = pd.concat([raw_df, df], ignore_index=True)

    return  nc_files_path

# %%
# Example usage

country = "GB"
data_folder = "data"
data_test_category = "test_data"
data_read_category = "raw_data"
data_save_category = "processed_data"
# output_folder = "ASOS_DATA"
output_folder2 ="ERA5_DATA
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~/opt/anaconda3/envs/graph_irp_2/lib/python3.9/site-packages/IPython/core/compilerop.py:86, in CachingCompiler.ast_parse(self, source, filename, symbol)
#      81 def ast_parse(self, source, filename='<unknown>', symbol='exec'):
#      82     """Parse code to an AST with the current compiler flags active.
#      83
#      84     Arguments are exactly the same as ast.parse (in the standard library),
#      85     and are passed to the built-in compile function."""
# ---> 86     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
# SyntaxError: EOL while scanning string literal (4200837596.py, line 9)

# %%
nc_file_path = extract_data_nc_to_xr(country, data_folder, data_test_category, output_folder2)
# Out:
# 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 9383.23it/s]

# %%
nc_file_path
# Out:
# ['/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/test_data/ERA5_DATA/GB_ERA5_DATA/era5_pressure_level_2022_02_1000.nc',
#  '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/test_data/ERA5_DATA/GB_ERA5_DATA/era5_single_level_2023_01.nc']

# %%
ds2 = xr.open_dataset(nc_file_path[0])

# %%
# Data Description
for i in ds2.data_vars:
    print("--------------------------------------------------------------------")
    print(i)
    print("--------------------------------------------------------------------")
    var_data = ds2[i]
    print(var_data)
# Out:
# --------------------------------------------------------------------
# r
# --------------------------------------------------------------------
# <xarray.DataArray 'r' (time: 672, latitude: 45, longitude: 41)>
# [1239840 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2022-02-01 ... 2022-02-28T23:00:00
# Attributes:
#     units:          %
#     long_name:      Relative humidity
#     standard_name:  relative_humidity
# --------------------------------------------------------------------
# q
# --------------------------------------------------------------------
# <xarray.DataArray 'q' (time: 672, latitude: 45, longitude: 41)>
# [1239840 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 -8.0 -7.75 -7.5 -7.25 ... 1.25 1.5 1.75 2.0
#   * latitude   (latitude) float32 61.0 60.75 60.5 60.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 2022-02-01 ... 2022-02-28T23:00:00
# Attributes:
#     units:          kg kg**-1
#     long_name:      Specific humidity
#     standard_name:  specific_humidity

# %%
# data values
for i in ds2.data_vars:
    var_data = ds2[i]
    print('----------------------------------------')
    print(var_data.values)
    print('----------------------------------------')
# Out:
# ----------------------------------------
# [[[80.47372  82.185234 83.93959  ... 77.920364 77.62262  76.74437 ]
#   [80.34091  81.25129  82.48941  ... 80.47372  80.92355  80.56797 ]
#   [80.482285 80.58296  81.1656   ... 80.94711  82.22379  83.34624 ]
#   ...
#   [86.52508  86.43511  86.23161  ... 84.020996 85.107025 84.79    ]
#   [85.91887  85.49474  85.077034 ... 79.12635  82.088844 83.26698 ]
#   [84.61863  84.014565 83.47048  ... 79.68972  81.8018   81.59616 ]]
#
#  [[78.822174 79.104935 78.920715 ... 81.60902  80.25308  79.818245]
#   [79.745415 80.06458  79.70471  ... 80.99424  80.81859  81.429085]
#   [81.10777  81.099205 80.67507  ... 78.775055 79.419815 80.67507 ]
#   ...
#   [88.16591  88.91992  89.2091   ... 84.3573   86.60434  88.05023 ]
#   [87.814606 88.14235  88.213036 ... 79.745415 82.57295  85.56543 ]
#   [86.78855  86.767136 86.767136 ... 80.72434  82.59223  84.22235 ]]
#
#  [[78.80076  79.02782  79.16063  ... 88.10807  87.61754  85.29981 ]
#   [79.60618  79.77754  79.90178  ... 84.17094  86.32372  86.115944]
#   [80.61723  81.15918  81.666855 ... 79.9382   82.46799  83.78536 ]
#   ...
#   [88.999176 89.38261  90.11734  ... 84.89925  86.53579  88.24516 ]
#   [88.61789  88.74213  89.39332  ... 82.8707   84.179504 86.14379 ]
#   [88.58147  88.305145 88.43367  ... 83.78108  84.3316   85.25697 ]]
#
#  ...
#
#  [[74.728676 76.75936  77.11923  ... 72.56732  73.5184   73.122116]
#   [77.11066  76.013916 74.325966 ... 73.4777   73.70048  73.36203 ]
#   [0.00386769 0.00382245 0.00376995 ... 0.00432794 0.00438985 0.00439318]
#   [0.00370947 0.00366792 0.00363983 ... 0.00433128 0.00439271 0.00445997]
#   ...
#   [0.00510844 0.00521476 0.005365   ... 0.00345482 0.00322351 0.00317541]
#   [0.00536119 0.00546369 0.00558727 ... 0.00341185 0.00318017 0.00311196]
#   [0.00560346 0.00570644 0.00570977 ... 0.00332363 0.00317351 0.00306184]]
#
#  [[0.00302672 0.00312684 0.00324267 ... 0.00398793 0.00414056 0.00424401]
#   [0.0031435  0.00323696 0.00327708 ... 0.00406901 0.00425401 0.00435378]
#   [0.00325506 0.0033247  0.00331946 ... 0.0042283  0.00432223 0.00438854]
#   ...
#   [0.00489213 0.00501368 0.00515773 ... 0.00370328 0.00338387 0.00325982]
#   [0.00523583 0.00535607 0.00549191 ... 0.0036709  0.00335756 0.00320315]
#   [0.00548334 0.00560394 0.0056412  ... 0.0034453  0.00328089 0.00313588]]
#
#  [[0.00280778 0.00283635 0.00288695 ... 0.00357745 0.00365804 0.00380531]
#   [0.0028273  0.00286742 0.00294469 ... 0.00368328 0.00374102 0.00387924]
#   [0.00288076 0.00292552 0.00300564 ... 0.00381674 0.00387495 0.0040052 ]
#   ...
#   [0.00472272 0.00482582 0.00492118 ... 0.00398746 0.0035178  0.00334899]
#   [0.00509428 0.00517392 0.00525916 ... 0.003864   0.00341482 0.00323744]
#   [0.00539512 0.00547429 0.00552381 ... 0.00344816 0.00329327 0.00313636]]]
# ----------------------------------------

# %% [markdown]
# ## Data Match

# %%
import os
import re
import xarray as xr
from utils import folder_utils
from tqdm import tqdm

# %%
# Example usage

country = "GB"
data_folder = "data"
data_test_category = "test_data"
data_read_category = "raw_data"
data_save_category = "processed_data"
# output_folder = "ASOS_DATA"
output_folder2 = "ERA5_DATA"

# %%
def extract_year_month_from_filename(filename):
    match = re.search(r"(\d{4})_(\d{2})", filename)
    if match:
        year = int(match.group(1))
        month = int(match.group(2))
        month = f"{month:02}"
        return year, month
    else:
        raise ValueError(f"Cannot extract year and month from filename: {filename}")

# %%
def save_era5_processed_data(
    merged_ds, year, month, country, data_folder, data_category, output_folder
):
    output_directory = folder_utils.create_folder(
        country, data_folder, data_category, output_folder
    )
    output_filename = f"{country}_ERA5_{year}_{month}_processed_data.nc"
    output_filepath = os.path.join(output_directory, output_filename)
    merged_ds.to_netcdf(output_filepath)
    print(f"{output_filename} done!")

# %%
def extract_merge_nc_data(
    country, data_folder, data_read_category, data_save_category, output_folder
):
    input_folder_path = folder_utils.find_folder(
        country, data_folder, data_read_category, output_folder
    )

    # Get all the single_level data filename
    nc_files_single_level = [
        f
        for f in os.listdir(input_folder_path)
        if f.endswith(".nc") and "single_level" in f
    ]

    # Create a new blank dataset to store the merged data
    # merged_ds = xr.Dataset()

    # Loop single_level files
    for nc_file_A in tqdm(nc_files_single_level):
        nc_file_path_A = os.path.join(input_folder_path, nc_file_A)

        #
        ds_A = xr.open_dataset(nc_file_path_A)

        # extract the corresponding year and month
        year_A, month_A = extract_year_month_from_filename(nc_file_A)

        # Build the pressure level file path
        nc_file_B = f"era5_pressure_level_{year_A}_{month_A}_1000.nc"
        nc_file_path_B = os.path.join(input_folder_path, nc_file_B)

        #
        ds_B = xr.open_dataset(nc_file_path_B)

        # Merge single_level and pressure level by the key "time" and overwrite ds_A
        ds_A = ds_A.combine_first(ds_B)

        # Close all dataset
        ds_A.close()
        ds_B.close()

        save_era5_processed_data(
            ds_A, year_A, month_A,country, data_folder, data_save_category, output_folder
        )

# %%
extract_merge_nc_data(
    country, data_folder, data_read_category, data_save_category, output_folder2
)
# Out:
#   0%|                                                        | 0/20 [00:00<?, ?it/s]
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#   5%|██▍                                             | 1/20 [00:01<00:19,  1.03s/it]
# GB_ERA5_2023_06_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  10%|████▊                                           | 2/20 [00:01<00:13,  1.29it/s]
# GB_ERA5_2022_08_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  15%|███████▏                                        | 3/20 [00:02<00:11,  1.52it/s]
# GB_ERA5_2023_02_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  20%|█████████▌                                      | 4/20 [00:02<00:09,  1.71it/s]
# GB_ERA5_2023_03_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  25%|████████████                                    | 5/20 [00:03<00:07,  1.88it/s]
# GB_ERA5_2023_07_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  30%|██████████████▍                                 | 6/20 [00:03<00:06,  2.02it/s]
# GB_ERA5_2022_09_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  35%|████████████████▊                               | 7/20 [00:03<00:05,  2.25it/s]
# GB_ERA5_2022_12_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  40%|███████████████████▏                            | 8/20 [00:04<00:05,  2.37it/s]
# GB_ERA5_2022_02_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  50%|███████████████████████▌                       | 10/20 [00:04<00:03,  3.04it/s]
# GB_ERA5_2022_06_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
# GB_ERA5_2023_08_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  55%|█████████████████████████▊                     | 11/20 [00:05<00:03,  2.97it/s]
# GB_ERA5_2022_07_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  60%|████████████████████████████▏                  | 12/20 [00:05<00:02,  2.94it/s]
# GB_ERA5_2022_03_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  65%|██████████████████████████████▌                | 13/20 [00:05<00:02,  2.99it/s]
# GB_ERA5_2022_04_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  70%|████████████████████████████████▉              | 14/20 [00:06<00:02,  2.66it/s]
# GB_ERA5_2022_10_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  75%|███████████████████████████████████▎           | 15/20 [00:06<00:01,  2.55it/s]
# GB_ERA5_2022_11_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  80%|█████████████████████████████████████▌         | 16/20 [00:07<00:01,  2.24it/s]
# GB_ERA5_2022_01_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
#  85%|███████████████████████████████████████▉       | 17/20 [00:07<00:01,  2.19it/s]
# GB_ERA5_2022_05_processed_data.nc done!
#  90%|██████████████████████████████████████████▎    | 18/20 [00:08<00:00,  2.30it/s]
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
# GB_ERA5_2023_04_processed_data.nc done!
#  95%|████████████████████████████████████████████▋  | 19/20 [00:08<00:00,  2.44it/s]
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
# GB_ERA5_2023_05_processed_data.nc done!
# Folder '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/processed_data/ERA5_DATA/GB_ERA5_DATA' created successfully.
# 100%|███████████████████████████████████████████████| 20/20 [00:08<00:00,  2.23it/s]
# GB_ERA5_2023_01_processed_data.nc done!

# %%
print("1")
# Out:
# 1

# %%
input_folder_path = folder_utils.find_folder(
    country, data_folder, data_read_category, output_folder2
)

# %%
input_folder_path
# Out:
# '/Users/ww721/JupyterNotebookPath/IRP_20220602/irp_ww721_bakcup/data/raw_data/ERA5_DATA/GB_ERA5_DATA'
